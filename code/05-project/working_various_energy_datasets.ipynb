# %%
import pandas as pd

# %%
df = pd.read_excel("energy_prod_ShiftProject.xls")

# %%
df.head()
# Out:
#   World TOP 20 Countries with highest primary energy production \n in 2014 (Mtoe)  \
# 0                           United States of America
# 1                                              China
# 2                      Russian Federation & U.S.S.R.
# 3                                       Saudi Arabia
# 4                                             Canada
#
#       Biodiesel Biomass and Waste Elec     Coal Fuel Ethanol      Gas  \
# 0 NaN   3.02846                6.79025  462.162      28.3345  665.602
# 1 NaN  0.675906                 3.7451  1622.25      1.27589  113.153
# 2 NaN         -               0.240757   170.44            -  547.823
# 3 NaN         -                      -        -            -  98.0778
# 4 NaN  0.172804               0.634566  36.7992      1.07347  138.876
#
#   Geothermal Elec Hydroelectricity  Nuclear      Oil  \
# 0         1.59664          22.2957  207.683  708.333
# 1       0.0139295          76.5262  34.0238  231.781
# ...

# %%
df.dtypes
# Out:
# World TOP 20 Countries with highest primary energy production \n in 2014 (Mtoe)     object
#                                                                                    float64
# Biodiesel                                                                           object
# Biomass and Waste Elec                                                              object
# Coal                                                                                object
# Fuel Ethanol                                                                        object
# Gas                                                                                 object
# Geothermal Elec                                                                     object
# Hydroelectricity                                                                    object
# Nuclear                                                                             object
# ...

# %%
df.shape
df.to_csv("energy_prod_ShiftProject.csv", index=False)

# %%
df = pd.read_csv("energy_prod_ShiftProject.csv", na_values=["-"])

# %%
df.dtypes
# Out:
# World TOP 20 Countries with highest primary energy production \n in 2014 (Mtoe)     object
#                                                                                    float64
# Biodiesel                                                                          float64
# Biomass and Waste Elec                                                             float64
# Coal                                                                               float64
# Fuel Ethanol                                                                       float64
# Gas                                                                                float64
# Geothermal Elec                                                                    float64
# Hydroelectricity                                                                   float64
# Nuclear                                                                            float64
# ...

# %%
df.sort_values(by='Oil', ascending=False).head(10)
# Out:
#    World TOP 20 Countries with highest primary energy production \n in 2014 (Mtoe)  \
# 0                            United States of America
# 3                                        Saudi Arabia
# 2                       Russian Federation & U.S.S.R.
# 1                                               China
# 4                                              Canada
# 11                               United Arab Emirates
# 8                          Iran (Islamic Republic of)
# 14                                               Iraq
# 10                                             Brazil
# 13                                             Mexico
#
#         Biodiesel  Biomass and Waste Elec         Coal  Fuel Ethanol  \
# 0  NaN   3.028458                6.790251   462.162002     28.334482
# 3  NaN        NaN                     NaN          NaN           NaN
# 2  NaN        NaN                0.240757   170.439639           NaN
# ...

# %%
df = pd.read_csv("usretechnicalpotential.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  urbanUtilityScalePV_GWh  urbanUtilityScalePV_GW  \
# 0     Alabama                    35850                      20
# 1      Alaska                      166                       0
# 2     Arizona                   121305                      52
# 3    Arkansas                    28960                      15
# 4  California                   246008                     111
#
#    urbanUtilityScalePV_km2  ruralUtilityScalePV_GWh  ruralUtilityScalePV_GW  \
# 0                      426                  3706838                    2114
# 1                        2                  8282976                    9005
# 2                     1096                 11867693                    5147
# 3                      332                  4986388                    2747
# 4                     2320                  8855917                    4010
#
#    ruralUtilityScalePV_km2  rooftopPV_GWh  rooftopPV_GW   CSP_GWh  \
# ...

# %%
df.shape
# Out:
# (51, 31)
