# %%
import pandas as pd

# %%
df_2018 = pd.read_csv("openpv-export-201808201545.csv")

# %%
df_2018.head()
# Out:
#   state date_installed  incentive_prog_names type  size_kw  appraised  \
# 0    TX     01/03/2018                   NaN  uir    5.775        NaN
# 1    PA     01/10/2018                   NaN  uir   10.890        NaN
# 2    VA     01/12/2018                   NaN  uir    9.570        NaN
# 3    NY     01/15/2018                   NaN  uir   15.180        NaN
# 4    MD     01/26/2018                   NaN  uir   66.660        NaN
#
#    zipcode install_type                      installer  cost_per_watt  \
# 0    76034  Residential                    Axium Solar            NaN
# 1    19335  Residential  Paradise Energy Solutions LLC           2.98
# 2    22802  Residential  Paradise Energy Solutions LLC           2.61
# 3    14551  Residential  Paradise Energy Solutions LLC           3.12
# 4    21218   Commercial  Paradise Energy Solutions LLC           4.24
#
#                        ...                        effic_1  cust_county  \
# ...

# %%
df_2018.shape
# Out:
# (77, 82)

# %%
df_2018.columns
# Out:
# Index(['state', 'date_installed', 'incentive_prog_names', 'type', 'size_kw',
#        'appraised', 'zipcode', 'install_type', 'installer', 'cost_per_watt',
#        'cost', 'lbnl_tts_version_year', 'lbnl_tts', 'city', 'utility_clean',
#        'tech_1', 'model1_clean', 'county', 'annual_PV_prod',
#        'annual_insolation', 'rebate', 'sales_tax_cost', 'tilt1',
#        'tracking_type', 'azimuth1', 'manuf2_clean', 'manuf3_clean',
#        'manuf1_clean', 'inv_man_clean', 'reported_annual_energy_prod',
#        'incentivetype', 'year_app_implied', 'year', 'npv_fit_real',
#        'application_implied', 'npv_pbi_real', 'other_incentive',
#        'appraised_cluster', 'inflation', 'other_incentive_real',
#        'zip_available', 'cust_city', 'pbi', 'pbi_real', 'pbi_length',
#        'application', 'fit_length', 'fit_rate', 'fit_payment',
#        '_3rdparty_implied', 'utility', 'install_price_real_w', 'install_price',
# ...

# %%
df_2017 = pd.read_csv("openpv-2017.csv")

# %%
df_2017.shape
# Out:
# (329, 82)

# %%
df_2017.head()
# Out:
#   state date_installed  incentive_prog_names type  size_kw  appraised  \
# 0    OK     01/01/2017                   NaN  uir     7.20        NaN
# 1    AL     01/04/2017                   NaN  uir  3000.00        NaN
# 2    TX     01/06/2017                   NaN  uir  1111.59        NaN
# 3    NY     01/06/2017                   NaN  uir    16.12        NaN
# 4    PA     01/06/2017                   NaN  uir    89.28        NaN
#
#    zipcode install_type                  installer  cost_per_watt  \
# 0    74055  Residential                        NaN           5.42
# 1    36912   Commercial                        NaN            NaN
# 2    75211   Commercial                Axium Solar            NaN
# 3    13041  Residential  Paradise Energy Solutions           3.25
# 4    17406   Commercial   Paradise EnergySolutions           2.50
#
#                        ...                        effic_1  cust_county  \
# 0                      ...                            NaN          NaN
# ...

# %%
df_2017.install_type.value_counts()
# Out:
# Residential     226
# Commercial       60
# Agricultural     35
# Government        5
# Unknown           1
# Nonprofit         1
# Educational       1
# Name: install_type, dtype: int64

# %%
# SEIA residential solar installations
residential = pd.read_excel("SEIA Resi data by state.xlsx", skiprows=1)

# %%
residential.shape
# Out:
# (46, 12)
