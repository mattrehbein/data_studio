# %%
import pandas as pd
import matplotlib.pyplot as plt
from cycler import cycler

# %matplotlib inline

# %%
plt.rcdefaults()
plt.rcParams.update({
  'patch.linewidth': 0.5,
  'patch.facecolor': '#e37e00',
  'patch.edgecolor': '#EEEEEE',
  'patch.antialiased': True,
  'font.size': 10.0,
  'font.family': 'Khmer Sangam MN',
  'axes.facecolor': 'white',
  'axes.edgecolor': 'white',
  'axes.linewidth': '1',
  'axes.grid': True,
  'grid.linewidth': '1',
  'legend.scatterpoints': '2',
  'axes.titlesize': 'large',
  'axes.labelsize': 'large',
  'axes.labelcolor': '#555555',
  'axes.axisbelow': True,
  'axes.prop_cycle': cycler('color', ['#C10534', '#ffd200', '#e37e00', '#00887d', '#7ad2f6', '#014d64', '#938DD2']),
  'xtick.major.bottom': True,
  'xtick.minor.bottom': True,
  'xtick.major.size': 7,
  'xtick.major.pad': 2,
  'xtick.direction': 'in',
  'xtick.labelsize': 'large',
  'ytick.left': True,
  'ytick.labelsize': 'large',
  'grid.color': '#d9e6eb',
  'grid.linestyle': '-',
  'figure.facecolor': 'white'
})

# %%
df = pd.read_excel("CPD gang database 11-17.xlsx")
df.head()
# Out:
#     AGE            RACE            GANG_NAME FACTION_NAME  BEAT_FIRST_ARREST  \
# 0  19.0           BLACK  12TH STREET PLAYERS          NaN                NaN
# 1  20.0           WHITE  12TH STREET PLAYERS          NaN                NaN
# 2  21.0  WHITE HISPANIC  12TH STREET PLAYERS          NaN                NaN
# 3  22.0  WHITE HISPANIC  12TH STREET PLAYERS          NaN                NaN
# 4  22.0  WHITE HISPANIC  12TH STREET PLAYERS          NaN                NaN
#
#   FIRST_ARREST
# 0   2016-01-01
# 1   2010-08-01
# 2   2012-11-01
# 3   2010-11-01
# 4   2008-08-01

# %%
from matplotlib.ticker import FuncFormatter

def with_commas(value, pos):
    return "{:,}".format(int(value))

formatter = FuncFormatter(with_commas)

# %%
color = plt.rcParams['axes.prop_cycle'].by_key()['color'][0]
ax = df.GANG_NAME.value_counts().head(20).plot(kind='barh', color=color, figsize=(15,10))

# ax.grid(False, axis='x')

ax.xaxis.set_major_formatter(formatter)

ax.set_title("Chicago's biggest gangs", fontweight='bold', pad=20)
ax.title.set_fontsize(35)
ax.title.set_fontname("Khmer Sangam MN")

ax.set_xlabel("Number of members, as recorded by police")
# ax.set_ylabel("")

plt.show()

# %%
# df.GANG_NAME.value_counts().head(10)
top_ten_list = ['GANGSTER DISCIPLES', 'LATIN KINGS', 'BLACK P STONES', 'FOUR CORNER HUSTLERS', 'BLACK DISCIPLES', 'CONSERVATIVE VICE LORDS', 'TRAVELING VICE LORDS', 'MANIAC LATIN DISCIPLES','SATAN DISCIPLES', 'TWO SIX']

# %%
top_ten = df[df.GANG_NAME.isin(top_ten_list)]
top_ten.GANG_NAME.value_counts()
# Out:
# GANGSTER DISCIPLES         36943
# LATIN KINGS                13116
# BLACK P STONES             10086
# FOUR CORNER HUSTLERS        8700
# BLACK DISCIPLES             6174
# CONSERVATIVE VICE LORDS     5423
# TRAVELING VICE LORDS        5123
# MANIAC LATIN DISCIPLES      3555
# SATAN DISCIPLES             3494
# TWO SIX                     3118
# Name: GANG_NAME, dtype: int64

# %%
top_ten.head()
# Out:
#        AGE   RACE        GANG_NAME                     FACTION_NAME  \
# 1573  18.0  BLACK  BLACK DISCIPLES         YOUNG MONEY  / TYMB(003)
# 1574  18.0  BLACK  BLACK DISCIPLES  82ND AND MARYLAND  (BRAIN DEAD)
# 1575  18.0  BLACK  BLACK DISCIPLES                              NaN
# 1576  18.0  BLACK  BLACK DISCIPLES                              NaN
# 1577  18.0  BLACK  BLACK DISCIPLES                         ADA PARK
#
#       BEAT_FIRST_ARREST FIRST_ARREST
# 1573              321.0   2010-02-01
# 1574              212.0   2014-04-01
# 1575              726.0   2011-11-01
# 1576              312.0   2013-07-01
# 1577             2234.0   2013-07-01

# %%
top_ten['RACE'] = top_ten['RACE'].str.title()
# Out:
# /Users/matthewrehbein/.pyenv/versions/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
top_ten['GANG_NAME'] = top_ten['GANG_NAME'].str.title()
top_ten.head()
# Out:
# /Users/matthewrehbein/.pyenv/versions/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#        AGE   RACE        GANG_NAME                     FACTION_NAME  \
# 1573  18.0  Black  Black Disciples         YOUNG MONEY  / TYMB(003)
# 1574  18.0  Black  Black Disciples  82ND AND MARYLAND  (BRAIN DEAD)
# 1575  18.0  Black  Black Disciples                              NaN
# 1576  18.0  Black  Black Disciples                              NaN
# 1577  18.0  Black  Black Disciples                         ADA PARK
#
#       BEAT_FIRST_ARREST FIRST_ARREST
# 1573              321.0   2010-02-01
# 1574              212.0   2014-04-01
# ...

# %%
top_ten.RACE.value_counts()
# Out:
# Black                      72820
# White Hispanic             19171
# White                       2967
# Black Hispanic               527
# Asian/Pacific Islander       150
# Unknown                       57
# Amer Ind/Alaskan Native       33
# Name: RACE, dtype: int64

# %%
# 'Asian/Pacific Islander': 'Native Hawaiian and Other Pacific Islander'
# 'Amer Ind/Alaskan Native': 'American Indian and Alaska Native'
top_ten.RACE.replace({"Asian/Pacific Islander": "Native Hawaiian and Other Pacific Islander",
                 "Amer Ind/Alaskan Native": "American Indian and Alaska Native"}, inplace=True)
# Out:
# /Users/matthewrehbein/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/generic.py:5886: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
top_ten.RACE.fillna("Unknown", inplace=True)
# df.Opioid_Related.fillna("False", inplace=True)
# Out:
# /Users/matthewrehbein/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/generic.py:5430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
color_dict = {
    'White': '#C10534',
    'Black': '#7ad2f6',
    'American Indian and Alaska Native': '#e37e00',
    'Native Hawaiian and Other Pacific Islander': '#76c0c1',
    'Unknown': '#014d64',
    'White Hispanic': '#ffd200',
    'Black Hispanic': '#00887d'
}

# %%
stack_colors = [color_dict[name] for name in top_ten.RACE]

# %%
# .unstack() turns a series object thingy into a dataframe
# .reset_index() give it a new index
race_df = top_ten.groupby('GANG_NAME')['RACE'].value_counts().unstack().reset_index().fillna(0)
race_df
# Out:
# RACE                GANG_NAME  American Indian and Alaska Native    Black  \
# 0             Black Disciples                                1.0   6144.0
# 1              Black P Stones                                2.0   9964.0
# 2     Conservative Vice Lords                                1.0   5335.0
# 3        Four Corner Hustlers                                0.0   8535.0
# 4          Gangster Disciples                                3.0  36277.0
# 5                 Latin Kings                               19.0    820.0
# 6      Maniac Latin Disciples                                2.0    392.0
# 7             Satan Disciples                                4.0    211.0
# 8        Traveling Vice Lords                                0.0   5075.0
# 9                     Two Six                                1.0     67.0
#
# RACE  Black Hispanic  Native Hawaiian and Other Pacific Islander  Unknown  \
# 0               10.0                                         4.0      1.0
# ...

# %%
# amer indian, black, black hisp, native hawaii, unknown, white, white his
stack_colors = ['#e37e00', '#7ad2f6', '#00887d', '#76c0c1', '#014d64', '#C10534', '#ffd200']

# %%
ax = race_df.plot(kind='barh', x='GANG_NAME', color=stack_colors, stacked=True, figsize=(15,7))

ax.xaxis.set_major_formatter(formatter)

ax.grid(False, axis='y')
ax.yaxis.label.set_visible(False)
ax.xaxis.label.set_visible(False)
ax.tick_params(which='major', left=False, bottom=False, grid_alpha=0.5)

plt.savefig("top_gangs_stacked.pdf", transparent=True)

plt.show()

# %%
ax = df.RACE.value_counts().plot(kind='barh', figsize=(15,5))
ax.xaxis.set_major_formatter(formatter)
plt.show()

# %%
# ax = df.RACE.value_counts().plot(kind='barh')
# ax.xaxis.set_major_formatter(formatter)
# plt.show()

series = df.RACE.value_counts()

# series.plot.pie(figsize=(6, 6)) *THIS IS FROM pandas documentation

series.plot.pie(figsize=(6, 6))
plt.show()

# %%
df.dtypes
# Out:
# AGE                         float64
# RACE                         object
# GANG_NAME                    object
# FACTION_NAME                 object
# BEAT_FIRST_ARREST           float64
# FIRST_ARREST         datetime64[ns]
# dtype: object

# %%
df.sort_values(by='FIRST_ARREST', ascending=False)
# Out:
#          AGE            RACE                GANG_NAME  \
# 107915  46.0  WHITE HISPANIC          SATAN DISCIPLES
# 104636  18.0  WHITE HISPANIC          SATAN DISCIPLES
# 28129   20.0           BLACK     FOUR CORNER HUSTLERS
# 122672  18.0           BLACK               VICE LORDS
# 78770   28.0           WHITE             LATIN COUNTS
# 22085   19.0           BLACK  CONSERVATIVE VICE LORDS
# 80738   21.0  WHITE HISPANIC              LATIN KINGS
# 96884   25.0  WHITE HISPANIC   MANIAC LATIN DISCIPLES
# 9635    18.0           BLACK           BLACK P STONES
# 37179   19.0           BLACK       GANGSTER DISCIPLES
# 116885  49.0           BLACK     TRAVELING VICE LORDS
# 47760   29.0           BLACK       GANGSTER DISCIPLES
# 82736   25.0  WHITE HISPANIC              LATIN KINGS
# 112552  20.0           BLACK     TRAVELING VICE LORDS
# 104651  18.0  WHITE HISPANIC          SATAN DISCIPLES
# 127793  50.0  WHITE HISPANIC                      NaN
# ...

# %%
ax = df.AGE.hist()

ax.yaxis.set_major_formatter(formatter)

plt.show()

# %%
df[df.AGE > 80].AGE.value_counts()
# Out:
# 117.0    17
# 81.0      2
# 132.0     1
# 82.0      1
# 84.0      1
# 131.0     1
# 83.0      1
# Name: AGE, dtype: int64

# %%
# df[df.AGE > 80].AGE.value_counts().plot(kind='bar')
# plt.show()

# TO FIX THIS, CREATE NEW DF WITH JUST MEMBERS UNDER 80; HERE YOU'RE PLOTTING VALUE COUNTS

ax = df[df.AGE < 80].AGE.value_counts().hist()
ax.xaxis.set_major_formatter(formatter)
plt.show()

# %%
from pywaffle import Waffle

# %%
len(df)
# df.RACE.value_counts().sum()
# 128025
# Out:
# 128037

# %%
df['RACE'] = df['RACE'].str.title()

# %%
df.RACE.value_counts()
# Out:
# Black                      89360
# White Hispanic             31522
# White                       5811
# Black Hispanic               877
# Asian/Pacific Islander       298
# Unknown                       98
# Amer Ind/Alaskan Native       59
# Name: RACE, dtype: int64

# %%
df.RACE.replace({"Asian/Pacific Islander": "Native Hawaiian and Other Pacific Islander",
    "Amer Ind/Alaskan Native": "American Indian and Alaska Native"}, inplace=True)

# %%
df.RACE.value_counts()
# Out:
# Black                                         89360
# White Hispanic                                31522
# White                                          5811
# Black Hispanic                                  877
# Native Hawaiian and Other Pacific Islander      298
# Unknown                                          98
# American Indian and Alaska Native                59
# Name: RACE, dtype: int64

# %%
calculated = df.RACE.value_counts(normalize=True) * 100
df_races = calculated.reset_index()
df_races
# Out:
#                                         index       RACE
# 0                                       Black  69.798867
# 1                              White Hispanic  24.621754
# 2                                       White   4.538957
# 3                              Black Hispanic   0.685022
# 4  Native Hawaiian and Other Pacific Islander   0.232767
# 5                                     Unknown   0.076548
# 6           American Indian and Alaska Native   0.046085

# %%
df_races = df_races.rename(columns={'index': 'race_name'})

# %%
df_races.loc[4, 'race_name'] = "Native Hawaiian and Other Pacific Islander"
df_races
# Out:
#                                     race_name       RACE
# 0                                       Black  69.798867
# 1                              White Hispanic  24.621754
# 2                                       White   4.538957
# 3                              Black Hispanic   0.685022
# 4  Native Hawaiian and Other Pacific Islander   0.232767
# 5                                     Unknown   0.076548
# 6           American Indian and Alaska Native   0.046085

# %%
df_races.loc[6, 'race_name'] = "American Indian and Alaska Native"
df_races
# Out:
#                                     race_name       RACE
# 0                                       Black  69.798867
# 1                              White Hispanic  24.621754
# 2                                       White   4.538957
# 3                              Black Hispanic   0.685022
# 4  Native Hawaiian and Other Pacific Islander   0.232767
# 5                                     Unknown   0.076548
# 6           American Indian and Alaska Native   0.046085

# %%
#     'Black': '#ffd200',df_races

# color_dict = {
#     'White': '#C10534',
#     'Black': '#7ad2f6',
#     'American Indian and Alaska Native': '#e37e00',
#     'Asian': '#938DD2',
#     'Native Hawaiian and Other Pacific Islander': '#76c0c1',
#     'Two or More Races': '#014d64',
#     'Hispanic or Latino': '#ffd200'
# }
# purple = #938DD2 was Asian
color_dict = {
    'White': '#C10534',
    'Black': '#7ad2f6',
    'American Indian and Alaska Native': '#e37e00',
    'Native Hawaiian and Other Pacific Islander': '#76c0c1',
    'Unknown': '#014d64',
    'White Hispanic': '#ffd200',
    'Black Hispanic': '#00887d'
}

# %%
waffle_colors = [color_dict[name] for name in df_races.race_name]

# %%
fig = plt.figure(
    FigureClass=Waffle,
    rows=10,
    values=list(calculated.values),
    labels=list(calculated.index),
    figsize=(9, 9),
    colors=waffle_colors,
    legend={'loc': 'upper left', 'bbox_to_anchor': (1.1, 1)}
)

plt.savefig("gang_race_waffle.pdf")
plt.show()
# Out:
# /Users/matthewrehbein/.pyenv/versions/3.6.5/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# <Waffle size 900x900 with 1 Axes>

# %%
# percentages of each race/ethnicity in gang database
calculated
# Out:
# BLACK                      69.798867
# WHITE HISPANIC             24.621754
# WHITE                       4.538957
# BLACK HISPANIC              0.685022
# ASIAN/PACIFIC ISLANDER      0.232767
# UNKNOWN                     0.076548
# AMER IND/ALASKAN NATIVE     0.046085
# Name: RACE, dtype: float64

# %%
# race_df = top_ten.groupby('GANG_NAME')['RACE'].value_counts().unstack().reset_index().fillna(0)
gangs_race = df.groupby('GANG_NAME').RACE.value_counts(normalize=True).unstack().reset_index().fillna(0)
gangs_race.head()
# Out:
# RACE            GANG_NAME  AMER IND/ALASKAN NATIVE  ASIAN/PACIFIC ISLANDER  \
# 0     12TH STREET PLAYERS                      0.0                     0.0
# 1             18TH STREET                      0.0                     0.0
# 2             35TH STREET                      0.0                     0.0
# 3        35TH STREET CREW                      0.0                     0.0
# 4                     ABM                      0.0                     0.0
#
# RACE   BLACK  BLACK HISPANIC  UNKNOWN  WHITE  WHITE HISPANIC
# 0     0.1625             0.0      0.0   0.45          0.3875
# 1     0.0000             0.0      0.0   0.00          1.0000
# 2     0.0000             0.0      0.0   0.25          0.7500
# 3     0.0000             0.0      0.0   0.50          0.5000
# 4     1.0000             0.0      0.0   0.00          0.0000

# %%
gangs_race.shape
# Out:
# (130, 8)

# %%
gangs_race.dtypes
# Out:
# RACE
# GANG_NAME                   object
# AMER IND/ALASKAN NATIVE    float64
# ASIAN/PACIFIC ISLANDER     float64
# BLACK                      float64
# BLACK HISPANIC             float64
# UNKNOWN                    float64
# WHITE                      float64
# WHITE HISPANIC             float64
# dtype: object

# %%
gangs_race.sort_values(by='WHITE', ascending=False).head(20)
# Out:
# RACE                  GANG_NAME  AMER IND/ALASKAN NATIVE  \
# 32                    DC EAGLES                 0.000000
# 112           THORNDALE JAGOFFS                 0.000000
# 85                 NORTH SIDERS                 0.000000
# 86                  NORTHSIDERS                 0.000000
# 123             WHITE SUPREMIST                 0.000000
# 122           WHITE SUPREMICIST                 0.000000
# 111   TAP BOYS (THE ARAB POSSE)                 0.000000
# 6                ALMIGHTY POPES                 0.000000
# 39                     GAYLORDS                 0.004049
# 47                 INSANE POPES                 0.006135
# 100           SIMON CITY ROYALS                 0.006148
# 3              35TH STREET CREW                 0.000000
# 48       INSANE SPANISH OUTLAWS                 0.000000
# 45                INSANE DEUCES                 0.002755
# 24                      C-NOTES                 0.000000
# ...

# %%
# ax.yaxis.set_major_formatter(formatter)

gangs_race.WHITE.hist(bins=20, color='#C10534')


plt.show()

# %%
# len(gangs_race[gangs_race.BLACK == 0]) OUTPUTS 34
len(gangs_race[gangs_race.WHITE == 0])
# Out:
# 38

# %%
# len(gangs_race[gangs_race.WHITE == 1]) OUTPUTS 7
len(gangs_race[gangs_race.BLACK == 1])
# Out:
# 6

# %%
gangs_race.BLACK.hist(bins=20, color='#7ad2f6')

#  'White': '#C10534',
plt.show()

# %%
gangs_race.WHITE.value_counts()
# Out:
# 0.000000    38
# 1.000000     7
# 0.250000     5
# 0.500000     2
# 0.076923     2
# 0.004115     1
# 0.586066     1
# 0.068966     1
# 0.128608     1
# 0.299065     1
# 0.098481     1
# 0.085923     1
# 0.154802     1
# 0.205195     1
# 0.123188     1
# 0.044118     1
# 0.265306     1
# 0.099174     1
# 0.238095     1
# 0.100000     1
# 0.064698     1
# 0.095406     1
# 0.077419     1
# 0.084682     1
# 0.003768     1
# 0.142857     1
# 0.004795     1
# 0.125000     1
# 0.071429     1
# 0.049107     1
#             ..
# 0.023810     1
# 0.001296     1
# 0.047619     1
# 0.001703     1
# 0.047945     1
# 0.086505     1
# 0.165871     1
# 0.004280     1
# 0.053812     1
# 0.073077     1
# 0.840491     1
# 0.149442     1
# 0.041041     1
# 0.008345     1
# 0.001366     1
# 0.129032     1
# 0.004253     1
# 0.004268     1
# 0.459459     1
# 0.006118     1
# 0.143713     1
# 0.141844     1
# 0.084337     1
# 0.099570     1
# 0.095000     1
# 0.450000     1
# 0.013514     1
# ...

# %%
# library & dataset
import seaborn as sns
# df = sns.load_dataset('iris')

# %%
# density plot with shade
sns.kdeplot(gangs_race['WHITE'], shade=True)

# sns.set(xlim=0,1)

plt.xlim(0,1)

plt.show()

# %%
race_gangs_numbers = df.groupby('GANG_NAME').RACE.value_counts().unstack().reset_index().fillna(0)

# %%
gangs_race.sort_values(by='WHITE', ascending=False).head(12)
# white_list = 

# tolist()
# white_list
# Out:
# RACE                  GANG_NAME  AMER IND/ALASKAN NATIVE  \
# 32                    DC EAGLES                 0.000000
# 112           THORNDALE JAGOFFS                 0.000000
# 85                 NORTH SIDERS                 0.000000
# 86                  NORTHSIDERS                 0.000000
# 123             WHITE SUPREMIST                 0.000000
# 122           WHITE SUPREMICIST                 0.000000
# 111   TAP BOYS (THE ARAB POSSE)                 0.000000
# 6                ALMIGHTY POPES                 0.000000
# 39                     GAYLORDS                 0.004049
# 47                 INSANE POPES                 0.006135
# 100           SIMON CITY ROYALS                 0.006148
# 3              35TH STREET CREW                 0.000000
#
# RACE  ASIAN/PACIFIC ISLANDER     BLACK  BLACK HISPANIC   UNKNOWN     WHITE  \
# 32                  0.000000  0.000000        0.000000  0.000000  1.000000
# ...

# %%
len(df)
# Out:
# 128037

# %%
ax = df.AGE.hist()

ax.yaxis.set_major_formatter(formatter)

plt.show()

# %%
df.sort_values(by='FIRST_ARREST').head()
# Out:
#         AGE   RACE                GANG_NAME  FACTION_NAME  BEAT_FIRST_ARREST  \
# 7336   55.0  BLACK          BLACK DISCIPLES           NaN                NaN
# 73099  63.0  BLACK       GANGSTER DISCIPLES  54TH & HOYNE                NaN
# 27417  69.0  BLACK  CONSERVATIVE VICE LORDS           NaN                NaN
# 27420  69.0  BLACK  CONSERVATIVE VICE LORDS           NaN                NaN
# 7191   53.0  BLACK          BLACK DISCIPLES      ADA PARK                NaN
#
#       FIRST_ARREST
# 7336    1984-01-01
# 73099   1984-01-01
# 27417   1984-01-01
# 27420   1984-01-01
# 7191    1984-01-01

# %%
df.head()
# Out:
#     AGE            RACE            GANG_NAME FACTION_NAME  BEAT_FIRST_ARREST  \
# 0  19.0           Black  12TH STREET PLAYERS          NaN                NaN
# 1  20.0           White  12TH STREET PLAYERS          NaN                NaN
# 2  21.0  White Hispanic  12TH STREET PLAYERS          NaN                NaN
# 3  22.0  White Hispanic  12TH STREET PLAYERS          NaN                NaN
# 4  22.0  White Hispanic  12TH STREET PLAYERS          NaN                NaN
#
#   FIRST_ARREST
# 0   2016-01-01
# 1   2010-08-01
# 2   2012-11-01
# 3   2010-11-01
# 4   2008-08-01

# %%
df[df.GANG_NAME == '35TH STREET CREW']
# Out:
#      AGE            RACE         GANG_NAME FACTION_NAME  BEAT_FIRST_ARREST  \
# 98  24.0  White Hispanic  35TH STREET CREW          NaN              922.0
# 99  25.0           White  35TH STREET CREW          NaN              922.0
#
#    FIRST_ARREST
# 98   2007-05-01
# 99   2007-04-01

# %%
len(gangs_race[gangs_race['BLACK'] > 0.5])
# Out:
# 36

# %%
len(gangs_race[gangs_race['WHITE'] > 0.5])
# Out:
# 11

# %%
# gang_members = df.GANG_NAME.value_counts().unstack().reset_index().fillna(0)
# gang_members.head()

gang_members = df.GANG_NAME.value_counts().reset_index().fillna(0)
gang_members.head()
# Out:
#                   index  GANG_NAME
# 0    GANGSTER DISCIPLES      36943
# 1           LATIN KINGS      13116
# 2        BLACK P STONES      10086
# 3  FOUR CORNER HUSTLERS       8700
# 4       BLACK DISCIPLES       6174

# %%
len(gang_members[gang_members['GANG_NAME'] > 100])
# Out:
# 59

# %%
len(gang_members[gang_members['GANG_NAME'] < 50])
# Out:
# 63
