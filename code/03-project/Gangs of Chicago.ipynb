# %%
import pandas as pd
import matplotlib.pyplot as plt
from cycler import cycler

# %matplotlib inline

# %%
df = pd.read_excel("CPD gang database 3-18.xlsx")

# %%
df.head()
# Out:
#     AGE RACE            GANG_NAME  O_BEAT        CREATED_DATE
# 0  19.0  BLK  12TH STREET PLAYERS     NaN 2017-04-01 02:49:21
# 1  20.0  WHI  12TH STREET PLAYERS     NaN 2012-06-06 03:41:36
# 2  22.0  WHI  12TH STREET PLAYERS     NaN 2013-01-05 01:55:17
# 3  22.0  WWH  12TH STREET PLAYERS     NaN 2012-11-20 20:08:11
# 4  22.0  WWH  12TH STREET PLAYERS     NaN 2014-10-06 23:33:01

# %%
df.shape
# Out:
# (128836, 5)

# %%
len(df.GANG_NAME.value_counts())
# Out:
# 130

# %%
# df.GANG_NAME.value_counts().head(50).plot(kind='barh', figsize=(20,15))
df.GANG_NAME.value_counts().head(20).plot(kind='barh', figsize=(15,10))

# %%
# df.GANG_NAME.value_counts()
big_gangs = ['GANGSTER DISCIPLES', 'LATIN KINGS', 'BLACK P STONES']
big_three = df[df.GANG_NAME.isin(big_gangs)]
big_three.groupby()
# Out:
# (60466, 5)

# %%
# cull list to remove errors like ages above a certain age; when's too old to be in a gang?
# Chicago police's view of city's gang landscape
# Chicago's gang landscape, through CPD's lens

# i want to explore this data to get a feel for police view of gangs, how many gangs, how many in them
# and also maybe pair this with some general pop and demographic data to see if there are any
# red flags on how dubious data may be (like, according to CPD X% of black males in Chicago are
# gang members)

# there's also gang data on https://catalog.data.gov/dataset/crimes-2001-to-present-398a4
# maybe compare cpd with info from this on number of gang-related crime?

# NOTES ON THE DATA (PROPUBLICA FLAGGED)
# Because of privacy concerns, the two files received from CPD do not include names or any
# records of juveniles

# GRAPHS:
# who are the gang members? graph by race, age and gender -- maybe bar by gang, with stacked bars
# for race
# number of entries over time (use date added column); are there spikes, dips in how many
# police were adding?

# %%
crime_df = pd.read_csv("Crimes_-_2001_to_present.csv")

# %%
crime_df.shape
# Out:
# (6654241, 22)

# %%
crime_df.head()
# Out:
#          ID Case Number                    Date                   Block  IUCR  \
# 0  10000092    HY189866  03/18/2015 07:44:00 PM         047XX W OHIO ST  041A
# 1  10000094    HY190059  03/18/2015 11:00:00 PM  066XX S MARSHFIELD AVE  4625
# 2  10000095    HY190052  03/18/2015 10:45:00 PM   044XX S LAKE PARK AVE  0486
# 3  10000096    HY190054  03/18/2015 10:30:00 PM    051XX S MICHIGAN AVE  0460
# 4  10000097    HY189976  03/18/2015 09:00:00 PM        047XX W ADAMS ST  031A
#
#     Primary Type              Description Location Description  Arrest  \
# 0        BATTERY      AGGRAVATED: HANDGUN               STREET   False
# 1  OTHER OFFENSE         PAROLE VIOLATION               STREET    True
# 2        BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 3        BATTERY                   SIMPLE            APARTMENT   False
# 4        ROBBERY           ARMED: HANDGUN             SIDEWALK   False
#
# ...

# %%
crime_df.columns
# tx_cols = TXco_df.columns.values.tolist()
# tx_cols
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')
