# %% [markdown]
# # Which US cities Americans are fleeing -- and which are luring more
#
# So, I wanted to look at public housing in Atlanta -- and maybe it's affect on homelessness -- but after spending all of lab on Monday and a good chunk on Tuesday searching online and calling the housing authority, I abandoned this due to lack of data (or at least, a lack of ability to find it).
#
# I pivoted quickly to Census data on population change in US cities with 50,000 or more people. I searched for a table of what I wanted on the Census website and then exported it as a csv. I opened the csv in Sublime and chopped off a garbage topline of weird metavalues, then opened it here with pandas. I dropped columns I didn't need and renamed those I did. I also created a new column for state to have the option to do analysis at that level.
#
# The results are actually marginally interesting, at least to me. Four out of the five that saw the biggest number drop in population are major American cities. Three out of the five that added the most are in Texas.
#
# My "nice-to-have" improvements would be more data and analysis: I'd like to try to get at why by probing number of jobs added (or lost) and other economic factors in the cities I'm looking at. I've also located Census on population change that compares the current number to 2010 levels, and the largest slice of time would likely produce more interesting results. More analysis would be needed of course to pay off/confirm using "fleeing" and "luring" in the above headline.

# %%
import pandas as pd

# %matplotlib inline

# %%
df = pd.read_csv("CLEANER_pop_change.csv")

# %%
df.shape
# Out:
# (758, 12)

# %%
df
# Out:
#             Id  Id2      Geography     Target Geo Id  Target Geo Id2  Rank  \
# 0    0100000US  NaN  United States  1620000US4827684         4827684     1
# 1    0100000US  NaN  United States  1620000US4850820         4850820     2
# 2    0100000US  NaN  United States  1620000US4857176         4857176     3
# 3    0100000US  NaN  United States  1620000US1902305         1902305     4
# 4    0100000US  NaN  United States  1620000US0407940          407940     5
# 5    0100000US  NaN  United States  1620000US4829336         4829336     6
# 6    0100000US  NaN  United States  1620000US0812415          812415     7
# 7    0100000US  NaN  United States  1620000US4727740         4727740     8
# 8    0100000US  NaN  United States  1620000US4845744         4845744     9
# 9    0100000US  NaN  United States  1620000US1652120         1652120    10
# 10   0100000US  NaN  United States  1620000US4826232         4826232    11
# 11   0100000US  NaN  United States  1620000US4105800         4105800    12
# 12   0100000US  NaN  United States  1620000US4813552         4813552    13
# 13   0100000US  NaN  United States  1620000US1217935         1217935    14
# 14   0100000US  NaN  United States  1620000US1224125         1224125    15
# 15   0100000US  NaN  United States  1620000US0636770          636770    16
# 16   0100000US  NaN  United States  1620000US0629504          629504    17
# 17   0100000US  NaN  United States  1620000US4846452         4846452    18
# 18   0100000US  NaN  United States  1620000US4751560         4751560    19
# 19   0100000US  NaN  United States  1620000US0639486          639486    20
# 20   0100000US  NaN  United States  1620000US3231900         3231900    21
# 21   0100000US  NaN  United States  1620000US4830644         4830644    22
# 22   0100000US  NaN  United States  1620000US4822660         4822660    23
# 23   0100000US  NaN  United States  1620000US4965330         4965330    24
# 24   0100000US  NaN  United States  1620000US4816432         4816432    25
# 25   0100000US  NaN  United States  1620000US0662364          662364    26
# 26   0100000US  NaN  United States  1620000US4548535         4548535    27
# 27   0100000US  NaN  United States  1620000US4970850         4970850    28
# 28   0100000US  NaN  United States  1620000US4944320         4944320    29
# 29   0100000US  NaN  United States  1620000US1207525         1207525    30
# ..         ...  ...            ...               ...             ...   ...
# 728  0100000US  NaN  United States  1620000US0150000          150000   729
# 729  0100000US  NaN  United States  1620000US1772000         1772000   730
# 730  0100000US  NaN  United States  1620000US5585300         5585300   731
# 731  0100000US  NaN  United States  1620000US3977000         3977000   732
# 732  0100000US  NaN  United States  1620000US4975360         4975360   733
# 733  0100000US  NaN  United States  1620000US1827000         1827000   734
# 734  0100000US  NaN  United States  1620000US1724582         1724582   735
# 735  0100000US  NaN  United States  1620000US1754820         1754820   736
# 736  0100000US  NaN  United States  1620000US0651182          651182   737
# 737  0100000US  NaN  United States  1620000US1831000         1831000   738
# 738  0100000US  NaN  United States  1620000US1751089         1751089   739
# 739  0100000US  NaN  United States  1620000US3757500         3757500   740
# 740  0100000US  NaN  United States  1620000US1770122         1770122   741
# 741  0100000US  NaN  United States  1620000US4261000         4261000   742
# 742  0100000US  NaN  United States  1620000US2404000         2404000   743
# 743  0100000US  NaN  United States  1620000US1718823         1718823   744
# 744  0100000US  NaN  United States  1620000US2205000         2205000   745
# 745  0100000US  NaN  United States  1620000US1705573         1705573   746
# 746  0100000US  NaN  United States  1620000US1714351         1714351   747
# 747  0100000US  NaN  United States  1620000US4224000         4224000   748
# 748  0100000US  NaN  United States  1620000US2572600         2572600   749
# 749  0100000US  NaN  United States  1620000US0203000          203000   750
# 750  0100000US  NaN  United States  1620000US1301052         1301052   751
# 751  0100000US  NaN  United States  1620000US1319000         1319000   752
# 752  0100000US  NaN  United States  1620000US2836000         2836000   753
# 753  0100000US  NaN  United States  1620000US2270000         2270000   754
# 754  0100000US  NaN  United States  1620000US1759000         1759000   755
# 755  0100000US  NaN  United States  1620000US4023950         4023950   756
# 756  0100000US  NaN  United States  1620000US2965000         2965000   757
# 757  0100000US  NaN  United States  1620000US5613150         5613150   758
#
#                                            Geography.1  \
# 0                   United States - Frisco city, Texas
# 1            United States - New Braunfels city, Texas
# 2             United States - Pflugerville city, Texas
# 3                    United States - Ankeny city, Iowa
# 4                United States - Buckeye city, Arizona
# 5               United States - Georgetown city, Texas
# 6           United States - Castle Rock town, Colorado
# 7             United States - Franklin city, Tennessee
# 8                 United States - McKinney city, Texas
# 9                 United States - Meridian city, Idaho
# 10            United States - Flower Mound town, Texas
# 11                   United States - Bend city, Oregon
# 12              United States - Cedar Park city, Texas
# 13                 United States - Doral city, Florida
# 14            United States - Fort Myers city, Florida
# 15             United States - Irvine city, California
# 16             United States - Gilroy city, California
# 17               United States - Mansfield city, Texas
# 18        United States - Murfreesboro city, Tennessee
# 19      United States - Lake Elsinore city, California
# 20              United States - Henderson city, Nevada
# 21               United States - Grapevine city, Texas
# 22                United States - Edinburg city, Texas
# 23               United States - St. George city, Utah
# 24                  United States - Conroe city, Texas
# 25            United States - Rocklin city, California
# 26   United States - Mount Pleasant town, South Car...
# 27             United States - South Jordan city, Utah
# 28                     United States - Lehi city, Utah
# 29        United States - Bonita Springs city, Florida
# ..                                                 ...
# 728               United States - Mobile city, Alabama
# 729         United States - Springfield city, Illinois
# 730         United States - West Allis city, Wisconsin
# 731                  United States - Toledo city, Ohio
# 732            United States - Taylorsville city, Utah
# 733                 United States - Gary city, Indiana
# 734            United States - Evanston city, Illinois
# 735         United States - Oak Lawn village, Illinois
# 736     United States - Newport Beach city, California
# 737              United States - Hammond city, Indiana
# 738   United States - Mount Prospect village, Illinois
# 739   United States - Rocky Mount city, North Carolina
# 740           United States - Skokie village, Illinois
# 741      United States - Pittsburgh city, Pennsylvania
# 742           United States - Baltimore city, Maryland
# 743             United States - Decatur city, Illinois
# 744        United States - Baton Rouge city, Louisiana
# 745              United States - Berwyn city, Illinois
# 746              United States - Cicero town, Illinois
# 747            United States - Erie city, Pennsylvania
# 748        United States - Waltham city, Massachusetts
# 749     United States - Anchorage municipality, Alaska
# 750               United States - Albany city, Georgia
# 751             United States - Columbus city, Georgia
# 752          United States - Jackson city, Mississippi
# 753         United States - Shreveport city, Louisiana
# 754              United States - Peoria city, Illinois
# 755                United States - Enid city, Oklahoma
# 756           United States - St. Louis city, Missouri
# 757               United States - Casper city, Wyoming
#
#                              Geography.2  \
# 0                     Frisco city, Texas
# 1              New Braunfels city, Texas
# 2               Pflugerville city, Texas
# 3                      Ankeny city, Iowa
# 4                  Buckeye city, Arizona
# 5                 Georgetown city, Texas
# 6             Castle Rock town, Colorado
# 7               Franklin city, Tennessee
# 8                   McKinney city, Texas
# 9                   Meridian city, Idaho
# 10              Flower Mound town, Texas
# 11                     Bend city, Oregon
# 12                Cedar Park city, Texas
# 13                   Doral city, Florida
# 14              Fort Myers city, Florida
# 15               Irvine city, California
# 16               Gilroy city, California
# 17                 Mansfield city, Texas
# 18          Murfreesboro city, Tennessee
# 19        Lake Elsinore city, California
# 20                Henderson city, Nevada
# 21                 Grapevine city, Texas
# 22                  Edinburg city, Texas
# 23                 St. George city, Utah
# 24                    Conroe city, Texas
# 25              Rocklin city, California
# 26   Mount Pleasant town, South Carolina
# 27               South Jordan city, Utah
# 28                       Lehi city, Utah
# 29          Bonita Springs city, Florida
# ..                                   ...
# 728                 Mobile city, Alabama
# 729           Springfield city, Illinois
# 730           West Allis city, Wisconsin
# 731                    Toledo city, Ohio
# 732              Taylorsville city, Utah
# 733                   Gary city, Indiana
# 734              Evanston city, Illinois
# 735           Oak Lawn village, Illinois
# 736       Newport Beach city, California
# 737                Hammond city, Indiana
# 738     Mount Prospect village, Illinois
# 739     Rocky Mount city, North Carolina
# 740             Skokie village, Illinois
# 741        Pittsburgh city, Pennsylvania
# 742             Baltimore city, Maryland
# 743               Decatur city, Illinois
# 744          Baton Rouge city, Louisiana
# 745                Berwyn city, Illinois
# 746                Cicero town, Illinois
# 747              Erie city, Pennsylvania
# 748          Waltham city, Massachusetts
# 749       Anchorage municipality, Alaska
# 750                 Albany city, Georgia
# 751               Columbus city, Georgia
# 752            Jackson city, Mississippi
# 753           Shreveport city, Louisiana
# 754                Peoria city, Illinois
# 755                  Enid city, Oklahoma
# 756             St. Louis city, Missouri
# 757                 Casper city, Wyoming
#
#      Population Estimate (as of July 1) - 2016  \
# 0                                       163816
# 1                                        73319
# 2                                        59507
# 3                                        58639
# 4                                        64639
# 5                                        67068
# 6                                        59255
# 7                                        74685
# 8                                       172984
# 9                                        95436
# 10                                       73503
# 11                                       90615
# 12                                       72630
# 13                                       58680
# 14                                       76741
# 15                                      266385
# 16                                       55396
# 17                                       66271
# 18                                      131433
# 19                                       64088
# 20                                      292005
# 21                                       52104
# 22                                       87179
# 23                                       81631
# 24                                       81630
# 25                                       62733
# 26                                       83856
# 27                                       68679
# 28                                       60743
# 29                                       54366
# ..                                         ...
# 728                                     191590
# 729                                     115734
# 730                                      60392
# 731                                     278606
# 732                                      60452
# 733                                      76595
# 734                                      75338
# 735                                      56524
# 736                                      86842
# 737                                      77230
# 738                                      54368
# 739                                      54979
# 740                                      64529
# 741                                     305017
# 742                                     616958
# 743                                      72805
# 744                                     227352
# 745                                      56067
# 746                                      83323
# 747                                      98289
# 748                                      63052
# 749                                     297376
# 750                                      73953
# 751                                     196307
# 752                                     169005
# 753                                     194394
# 754                                     114351
# 755                                      50785
# 756                                     313144
# 757                                      58906
#
#      Population Estimate (as of July 1) - 2017  Change, 2016 to 2017 - Number  \
# 0                                       177286                          13470
# 1                                        79152                           5833
# 2                                        63359                           3852
# 3                                        62416                           3777
# 4                                        68453                           3814
# 5                                        70685                           3617
# 6                                        62276                           3021
# 7                                        78321                           3636
# 8                                       181330                           8346
# 9                                        99926                           4490
# 10                                       76681                           3178
# 11                                       94520                           3905
# 12                                       75704                           3074
# 13                                       61130                           2450
# 14                                       79943                           3202
# 15                                      277453                          11068
# 16                                       57664                           2268
# 17                                       68928                           2657
# 18                                      136372                           4939
# 19                                       66411                           2323
# 20                                      302539                          10534
# 21                                       53982                           1878
# 22                                       90280                           3101
# 23                                       84405                           2774
# 24                                       84378                           2748
# 25                                       64838                           2105
# 26                                       86668                           2812
# 27                                       70954                           2275
# 28                                       62712                           1969
# 29                                       56088                           1722
# ..                                         ...                            ...
# 728                                     190265                          -1325
# 729                                     114868                           -866
# 730                                      59934                           -458
# 731                                     276491                          -2115
# 732                                      59992                           -460
# 733                                      76008                           -587
# 734                                      74756                           -582
# 735                                      56087                           -437
# 736                                      86160                           -682
# 737                                      76618                           -612
# 738                                      53930                           -438
# 739                                      54523                           -456
# 740                                      63978                           -551
# 741                                     302407                          -2610
# 742                                     611648                          -5310
# 743                                      72174                           -631
# 744                                     225374                          -1978
# 745                                      55550                           -517
# 746                                      82552                           -771
# 747                                      97369                           -920
# 748                                      62442                           -610
# 749                                     294356                          -3020
# 750                                      73179                           -774
# 751                                     194058                          -2249
# 752                                     166965                          -2040
# 753                                     192036                          -2358
# 754                                     112883                          -1468
# 755                                      50122                           -663
# 756                                     308626                          -4518
# 757                                      57814                          -1092
#
#      Change, 2016 to 2017 - Percent [1]
# 0                                   8.2
# 1                                   8.0
# 2                                   6.5
# 3                                   6.4
# 4                                   5.9
# 5                                   5.4
# 6                                   5.1
# 7                                   4.9
# 8                                   4.8
# 9                                   4.7
# 10                                  4.3
# 11                                  4.3
# 12                                  4.2
# 13                                  4.2
# 14                                  4.2
# 15                                  4.2
# 16                                  4.1
# 17                                  4.0
# 18                                  3.8
# 19                                  3.6
# 20                                  3.6
# 21                                  3.6
# 22                                  3.6
# 23                                  3.4
# 24                                  3.4
# 25                                  3.4
# 26                                  3.4
# 27                                  3.3
# 28                                  3.2
# 29                                  3.2
# ..                                  ...
# 728                                -0.7
# 729                                -0.7
# 730                                -0.8
# 731                                -0.8
# 732                                -0.8
# 733                                -0.8
# 734                                -0.8
# 735                                -0.8
# 736                                -0.8
# 737                                -0.8
# 738                                -0.8
# 739                                -0.8
# 740                                -0.9
# 741                                -0.9
# 742                                -0.9
# 743                                -0.9
# 744                                -0.9
# 745                                -0.9
# 746                                -0.9
# 747                                -0.9
# 748                                -1.0
# 749                                -1.0
# 750                                -1.0
# 751                                -1.1
# 752                                -1.2
# 753                                -1.2
# 754                                -1.3
# 755                                -1.3
# 756                                -1.4
# 757                                -1.9
#
# [758 rows x 12 columns]

# %%
# cl_df = cl_df.drop(['name'], axis=1)
# cols = ['name', 'court', 'incumbent', 'vacancy_date', 'vacancy_reason', 'nom_date', 'confirm_date']
# df = df[cols]
# df
columns = df.columns.values.tolist()
columns
# Out:
# ['Id',
#  'Id2',
#  'Geography',
#  'Target Geo Id',
#  'Target Geo Id2',
#  'Rank',
#  'Geography.1',
#  'Geography.2',
#  'Population Estimate (as of July 1) - 2016',
#  'Population Estimate (as of July 1) - 2017',
#  'Change, 2016 to 2017 - Number',
#  'Change, 2016 to 2017 - Percent [1]']

# %%
my_cols = ['Geography.2', 'Population Estimate (as of July 1) - 2016', 'Population Estimate (as of July 1) - 2017', 'Change, 2016 to 2017 - Number', 'Change, 2016 to 2017 - Percent [1]']

# %%
df = df[my_cols]
df.head()
# Out:
#                  Geography.2  Population Estimate (as of July 1) - 2016  \
# 0         Frisco city, Texas                                     163816
# 1  New Braunfels city, Texas                                      73319
# 2   Pflugerville city, Texas                                      59507
# 3          Ankeny city, Iowa                                      58639
# 4      Buckeye city, Arizona                                      64639
#
#    Population Estimate (as of July 1) - 2017  Change, 2016 to 2017 - Number  \
# 0                                     177286                          13470
# 1                                      79152                           5833
# 2                                      63359                           3852
# 3                                      62416                           3777
# 4                                      68453                           3814
#
#    Change, 2016 to 2017 - Percent [1]
# 0                                 8.2
# 1                                 8.0
# 2                                 6.5
# 3                                 6.4
# 4                                 5.9

# %%
df.rename(index=str, columns={"Geography.2": "City"}, inplace=True)
df.head()
# Out:
# /Users/matthewrehbein/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py:3778: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#                         City  Population Estimate (as of July 1) - 2016  \
# 0         Frisco city, Texas                                     163816
# 1  New Braunfels city, Texas                                      73319
# 2   Pflugerville city, Texas                                      59507
# 3          Ankeny city, Iowa                                      58639
# 4      Buckeye city, Arizona                                      64639
#
#    Population Estimate (as of July 1) - 2017  Change, 2016 to 2017 - Number  \
# 0                                     177286                          13470
# 1                                      79152                           5833
# 2                                      63359                           3852
# 3                                      62416                           3777
# 4                                      68453                           3814
#
#    Change, 2016 to 2017 - Percent [1]
# 0                                 8.2
# 1                                 8.0
# 2                                 6.5
# 3                                 6.4
# 4                                 5.9

# %%
df.rename(index=str, columns={"Population Estimate (as of July 1) - 2016": "2016_Pop"}, inplace=True)
# Out:
# /Users/matthewrehbein/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py:3778: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df.rename(index=str, columns={"Population Estimate (as of July 1) - 2017": "2017_Pop"}, inplace=True)
# Out:
# /Users/matthewrehbein/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py:3778: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df.rename(index=str, columns={"Change, 2016 to 2017 - Number": "Pop_Change"}, inplace=True)
# Out:
# /Users/matthewrehbein/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py:3778: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df.rename(index=str, columns={"Change, 2016 to 2017 - Percent [1]": "Percent_Change"}, inplace=True)
# Out:
# /Users/matthewrehbein/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py:3778: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df['City'] = df.City.str.replace(" city", "")
# Out:
# /Users/matthewrehbein/.pyenv/versions/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['State'] = df.City.str.split(", ").str[1]
# Out:
# /Users/matthewrehbein/.pyenv/versions/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#                    City  2016_Pop  2017_Pop  Pop_Change  Percent_Change  \
# 0         Frisco, Texas    163816    177286       13470             8.2
# 1  New Braunfels, Texas     73319     79152        5833             8.0
# 2   Pflugerville, Texas     59507     63359        3852             6.5
# 3          Ankeny, Iowa     58639     62416        3777             6.4
# 4      Buckeye, Arizona     64639     68453        3814             5.9
#
#      State
# 0    Texas
# 1    Texas
# 2    Texas
# 3     Iowa
# 4  Arizona

# %%
df.to_csv("my_pop_df.csv", index=False)

# %%
df.dtypes
# Out:
# City               object
# 2016_Pop            int64
# 2017_Pop            int64
# Pop_Change          int64
# Percent_Change    float64
# State              object
# dtype: object

# %%
# which US cities gained the most ppl and which lost most?
df.sort_values(by='Percent_Change', ascending=False).head()
# Out:
#                    City  2016_Pop  2017_Pop  Pop_Change  Percent_Change  \
# 0         Frisco, Texas    163816    177286       13470             8.2
# 1  New Braunfels, Texas     73319     79152        5833             8.0
# 2   Pflugerville, Texas     59507     63359        3852             6.5
# 3          Ankeny, Iowa     58639     62416        3777             6.4
# 4      Buckeye, Arizona     64639     68453        3814             5.9
#
#      State
# 0    Texas
# 1    Texas
# 2    Texas
# 3     Iowa
# 4  Arizona

# %%
df.sort_values(by='Percent_Change').head()
# Out:
#                       City  2016_Pop  2017_Pop  Pop_Change  Percent_Change  \
# 757        Casper, Wyoming     58906     57814       -1092            -1.9
# 756    St. Louis, Missouri    313144    308626       -4518            -1.4
# 754       Peoria, Illinois    114351    112883       -1468            -1.3
# 755         Enid, Oklahoma     50785     50122        -663            -1.3
# 753  Shreveport, Louisiana    194394    192036       -2358            -1.2
#
#          State
# 757    Wyoming
# 756   Missouri
# 754   Illinois
# 755   Oklahoma
# 753  Louisiana

# %%
df.sort_values(by='Pop_Change', ascending=False).head()
# Out:
#                         City  2016_Pop  2017_Pop  Pop_Change  Percent_Change  \
# 143       San Antonio, Texas   1487738   1511946       24208             1.6
# 167         Phoenix, Arizona   1602042   1626078       24036             1.5
# 183            Dallas, Texas   1322140   1341075       18935             1.4
# 82         Fort Worth, Texas    855504    874168       18664             2.2
# 408  Los Angeles, California   3981116   3999759       18643             0.5
#
#           State
# 143       Texas
# 167     Arizona
# 183       Texas
# 82        Texas
# 408  California

# %%
df.sort_values(by='Pop_Change').head()
# Out:
#                                City  2016_Pop  2017_Pop  Pop_Change  \
# 742             Baltimore, Maryland    616958    611648       -5310
# 756             St. Louis, Missouri    313144    308626       -4518
# 611               Chicago, Illinois   2720275   2716450       -3825
# 749  Anchorage municipality, Alaska    297376    294356       -3020
# 741        Pittsburgh, Pennsylvania    305017    302407       -2610
#
#      Percent_Change         State
# 742            -0.9      Maryland
# 756            -1.4      Missouri
# 611            -0.1      Illinois
# 749            -1.0        Alaska
# 741            -0.9  Pennsylvania

# %%
gain_df = df.sort_values(by='Pop_Change', ascending=False).head()
ax = gain_df.sort_values(by='Pop_Change', ascending=True).plot(kind='barh', color='lightgreen', x='City', y='Pop_Change', figsize=(10,3))

ax.set_title("Biggest Population Growth", pad=20)
ax.title.set_fontsize(25)
ax.title.set_fontname("Arial")

ax.tick_params(which='major', left=False, bottom=False, grid_alpha=0.5)

ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)

# %%
ax2 = df.sort_values(by='Pop_Change').head()
ax2.sort_values(by='Pop_Change', ascending=False).plot(kind='barh', color='darkred', x='City', y='Pop_Change', figsize=(10,3), title="Biggest Population Loss")

# %%
# all_gains = df[~df['Pop_Change'].str.contains('-')]
all_gains = df[df['Pop_Change'] > 0]
bigger_cities_by_state = all_gains.State.value_counts()

# %%
bigger_cities_by_state.head(10).sort_values(ascending=True).plot(kind='barh', color='lightgreen', title='Number of Growing Cities by State')

# %%
# bigger_cities_by_state.plot(marker='o', linestyle='')
# # df.plot.scatter('x', 'y')

# %%
# eco_df = pd.read_csv("TX_unemploy_CLEAN.csv")
# eco_df.head(10)

# %%
TXeco_df = pd.read_excel("UnemploymentReport.xlsx", skiprows=1)
TXeco_df.head()
# Out:
#    FIPS                  Name  2009  2010  2011  2012  2013  2014  2015  2016  \
# 0  48000                Texas   7.6   8.1   7.8   6.7   6.3   5.1   4.4   4.6
# 1  48001  Anderson County, TX   8.7   8.1   7.3   6.3   5.8   4.7   3.9   4.3
# 2  48003   Andrews County, TX   7.0   6.2   5.0   4.0   3.8   3.0   3.5   4.7
# 3  48005  Angelina County, TX   8.2   8.5   7.9   6.9   6.5   5.2   5.6   5.9
# 4  48007   Aransas County, TX   6.8   9.2   8.8   7.0   6.6   5.5   5.1   5.6
#
#    2017  NaN  Median Household Income (2016)  % of State Median HH Income
# 0   4.3  NaN                         56583.0                     1.000000
# 1   3.6  NaN                         43967.0                     0.777036
# 2   3.1  NaN                         60644.0                     1.071771
# 3   5.1  NaN                         43658.0                     0.771575
# 4   6.8  NaN                         44866.0                     0.792924

# %%
TXeco_df.shape
# Out:
# (258, 14)

# %%
TXeco_df[(TXeco_df.Name == 'Bexar County, TX') | (TXeco_df.Name == 'Dallas County, TX') | (TXeco_df.Name == 'Tarrant County, TX')]

# TXeco_df[(TXeco_df.Name.str.contains("Bexar", na=False)) | (TXeco_df.Name.str.contains("Dallas", na=False)) | (TXeco_df.Name.str.contains("Tarrant", na=False))]
# Out:
#      FIPS                 Name  2009  2010  2011  2012  2013  2014  2015  \
# 15   48029    Bexar County, TX   6.7   7.3   7.2   6.3   5.8   4.7   3.8
# 57   48113   Dallas County, TX   8.2   8.6   8.1   7.1   6.6   5.4   4.3
# 220  48439  Tarrant County, TX   7.7   8.1   7.6   6.5   6.0   5.0   4.2
#
#      2016  2017  NaN  Median Household Income (2016)  \
# 15    3.7   3.5  NaN                         53170.0
# 57    4.0   3.8  NaN                         54429.0
# 220   4.0   3.7  NaN                         61553.0
#
#      % of State Median HH Income
# 15                      0.939682
# 57                      0.961932
# 220                     1.087836

# %%
my_counties = ['Bexar County, TX', 'Dallas County, TX', 'Tarrant County, TX']

# %%
TXco_df = TXeco_df[TXeco_df['Name'].isin(my_counties)]
TXco_df
# Out:
#      FIPS                 Name  2009  2010  2011  2012  2013  2014  2015  \
# 15   48029    Bexar County, TX   6.7   7.3   7.2   6.3   5.8   4.7   3.8
# 57   48113   Dallas County, TX   8.2   8.6   8.1   7.1   6.6   5.4   4.3
# 220  48439  Tarrant County, TX   7.7   8.1   7.6   6.5   6.0   5.0   4.2
#
#      2016  2017  NaN  Median Household Income (2016)  \
# 15    3.7   3.5  NaN                         53170.0
# 57    4.0   3.8  NaN                         54429.0
# 220   4.0   3.7  NaN                         61553.0
#
#      % of State Median HH Income
# 15                      0.939682
# 57                      0.961932
# 220                     1.087836

# %%
TXco_df['City'] = ['San Antonio, Texas', 'Dallas, Texas', 'Fort Worth, Texas']
# Out:
# /Users/matthewrehbein/.pyenv/versions/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
TXco_df
# Out:
#      FIPS                 Name  2009  2010  2011  2012  2013  2014  2015  \
# 15   48029    Bexar County, TX   6.7   7.3   7.2   6.3   5.8   4.7   3.8
# 57   48113   Dallas County, TX   8.2   8.6   8.1   7.1   6.6   5.4   4.3
# 220  48439  Tarrant County, TX   7.7   8.1   7.6   6.5   6.0   5.0   4.2
#
#      2016  2017  NaN  Median Household Income (2016)  \
# 15    3.7   3.5  NaN                         53170.0
# 57    4.0   3.8  NaN                         54429.0
# 220   4.0   3.7  NaN                         61553.0
#
#      % of State Median HH Income                City
# 15                      0.939682  San Antonio, Texas
# 57                      0.961932       Dallas, Texas
# 220                     1.087836   Fort Worth, Texas

# %%
addTX_df = pd.merge(ax, TXco_df, on='City', how='outer')
addTX_df
# Out:
#                       City  2016_Pop  2017_Pop  Pop_Change  Percent_Change  \
# 0       San Antonio, Texas   1487738   1511946       24208             1.6
# 1         Phoenix, Arizona   1602042   1626078       24036             1.5
# 2            Dallas, Texas   1322140   1341075       18935             1.4
# 3        Fort Worth, Texas    855504    874168       18664             2.2
# 4  Los Angeles, California   3981116   3999759       18643             0.5
#
#         State  FIPS                 Name  2009  2010  2011  2012  2013  2014  \
# 0       Texas  48029    Bexar County, TX   6.7   7.3   7.2   6.3   5.8   4.7
# 1     Arizona    NaN                 NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2       Texas  48113   Dallas County, TX   8.2   8.6   8.1   7.1   6.6   5.4
# 3       Texas  48439  Tarrant County, TX   7.7   8.1   7.6   6.5   6.0   5.0
# 4  California    NaN                 NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2015  2016  2017  NaN  Median Household Income (2016)  \
# 0   3.8   3.7   3.5  NaN                         53170.0
# 1   NaN   NaN   NaN  NaN                             NaN
# 2   4.3   4.0   3.8  NaN                         54429.0
# 3   4.2   4.0   3.7  NaN                         61553.0
# 4   NaN   NaN   NaN  NaN                             NaN
#
#    % of State Median HH Income
# 0                     0.939682
# 1                          NaN
# 2                     0.961932
# 3                     1.087836
# 4                          NaN

# %%
CAeco_df = pd.read_excel("CAunemploymentReport.xlsx", skiprows=1)

# %%
LACo_df = CAeco_df[CAeco_df.Name == "Los Angeles County, CA"]
LACo_df
# Out:
#     FIPS                     Name  2009  2010  2011  2012  2013  2014  2015  \
# 19  06037  Los Angeles County, CA  11.6  12.5  12.2  10.9   9.8   8.3   6.6
#
#     2016  2017  NaN  Median Household Income (2016)  \
# 19   5.3   4.7  NaN                         61308.0
#
#     % of State Median HH Income
# 19                     0.905383

# %%
# Sophie's idea:
# if df['name'] == 'California':
#     df['FIPS'] = LACo_df['FIPS']
#     df['2009'] = LACo_df['2009']
#     df['2010'] = LACo_df['2010']

# %%
LACo_df['City'] = "Los Angeles, California"
LACo_df
# Out:
# /Users/matthewrehbein/.pyenv/versions/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#     FIPS                     Name  2009  2010  2011  2012  2013  2014  2015  \
# 19  06037  Los Angeles County, CA  11.6  12.5  12.2  10.9   9.8   8.3   6.6
#
#     2016  2017  NaN  Median Household Income (2016)  \
# 19   5.3   4.7  NaN                         61308.0
#
#     % of State Median HH Income                     City
# 19                     0.905383  Los Angeles, California

# %%
merged = addTX_df.merge(LACo_df, left_on='City', right_on='City')
merged
# Out:
#                       City  2016_Pop  2017_Pop  Pop_Change  Percent_Change  \
# 0  Los Angeles, California   3981116   3999759       18643             0.5
#
#         State FIPS _x Name_x  2009_x  2010_x              ...                \
# 0  California     NaN    NaN     NaN     NaN              ...
#
#    2011_y  2012_y  2013_y  2014_y  2015_y  2016_y  2017_y  None_y  \
# 0    12.2    10.9     9.8     8.3     6.6     5.3     4.7     NaN
#
#    Median Household Income (2016)_y  % of State Median HH Income_y
# 0                           61308.0                       0.905383
#
# [1 rows x 34 columns]

# %%
# merged_columns = merged.columns.values.tolist()
# merged_columns

# %%
merged['FIPS _x'].fillna(merged['FIPS _y'], inplace=True)
merged['Name_x'].fillna(merged['Name_y'], inplace=True)
merged['2009_x'].fillna(merged['2009_y'], inplace=True)
merged['2010_x'].fillna(merged['2010_y'], inplace=True)
merged['2011_x'].fillna(merged['2011_y'], inplace=True)
merged['2012_x'].fillna(merged['2012_y'], inplace=True)
merged['2013_x'].fillna(merged['2013_y'], inplace=True)
merged['2014_x'].fillna(merged['2014_y'], inplace=True)
merged['2015_x'].fillna(merged['2015_y'], inplace=True)
merged['2016_x'].fillna(merged['2016_y'], inplace=True)
merged['2017_x'].fillna(merged['2017_y'], inplace=True)
merged['None_x'].fillna(merged['None_y'], inplace=True)
merged['Median Household Income (2016)_x'].fillna(merged['Median Household Income (2016)_y'], inplace=True)
merged['% of State Median HH Income_x'].fillna(merged['% of State Median HH Income_y'], inplace=True)
merged
# Out:
#                       City  2016_Pop  2017_Pop  Pop_Change  Percent_Change  \
# 0  Los Angeles, California   3981116   3999759       18643             0.5
#
#         State FIPS _x                  Name_x  2009_x  2010_x  \
# 0  California   06037  Los Angeles County, CA    11.6    12.5
#
#                ...                2011_y  2012_y  2013_y  2014_y  2015_y  \
# 0              ...                  12.2    10.9     9.8     8.3     6.6
#
#    2016_y  2017_y  None_y  Median Household Income (2016)_y  \
# 0     5.3     4.7     NaN                           61308.0
#
#    % of State Median HH Income_y
# 0                       0.905383
#
# [1 rows x 34 columns]

# %%
# RERUN FROM TOP TO RECREATE THE addTX_df BEFORE I CREATED ALL THESE GARBAGE COLUMNS
# THEN RUN BELOW TO GET EXACT COLUMN NAMES AND ADD VALUES BELOW OR FIRST TRY USING COLUMN NUMBER
# (STARTING AT 0), RATHER THAN THE EXACT NAME; TRY THAT ON ONE CELL FIRST
columns = addTX_df.columns.values.tolist()
columns
# Out:
# ['City',
#  '2016_Pop',
#  '2017_Pop',
#  'Pop_Change',
#  'Percent_Change',
#  'State',
#  'FIPS ',
#  'Name',
#  '2009',
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  '2017',
#  None,
#  'Median Household Income (2016)',
#  '% of State Median HH Income',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016']

# %%
# q_df.loc[3, 'last_employer'] = "2015 - present Michigan Supreme Court"
# addTX_df.dtypes
addTX_df.loc[4, 'FIPS '] = '06037'
# addTX_df = addTX_df.drop(['FIPS'], axis=1)
# Out:
#                       City  2016_Pop  2017_Pop  Pop_Change  Percent_Change  \
# 0       San Antonio, Texas   1487738   1511946       24208             1.6
# 1         Phoenix, Arizona   1602042   1626078       24036             1.5
# 2            Dallas, Texas   1322140   1341075       18935             1.4
# 3        Fort Worth, Texas    855504    874168       18664             2.2
# 4  Los Angeles, California   3981116   3999759       18643             0.5
#
#         State  FIPS                 Name  2009  2010  2011  2012  2013  2014  \
# 0       Texas  48029    Bexar County, TX   6.7   7.3   7.2   6.3   5.8   4.7
# 1     Arizona    NaN                 NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2       Texas  48113   Dallas County, TX   8.2   8.6   8.1   7.1   6.6   5.4
# 3       Texas  48439  Tarrant County, TX   7.7   8.1   7.6   6.5   6.0   5.0
# 4  California  06037                 NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2015  2016  2017  NaN  Median Household Income (2016)  \
# 0   3.8   3.7   3.5  NaN                         53170.0
# 1   NaN   NaN   NaN  NaN                             NaN
# 2   4.3   4.0   3.8  NaN                         54429.0
# 3   4.2   4.0   3.7  NaN                         61553.0
# 4   NaN   NaN   NaN  NaN                             NaN
#
#    % of State Median HH Income
# 0                     0.939682
# 1                          NaN
# 2                     0.961932
# 3                     1.087836
# 4                          NaN

# %%
addTX_df.loc[4, 'Name'] = 'Los Angeles County, CA'
addTX_df.loc[4, '2009'] = 11.6
addTX_df.loc[4, '2010'] = 12.5
addTX_df.loc[4, '2011'] = 12.2
addTX_df.loc[4, '2012'] = 10.9
addTX_df.loc[4, '2013'] = 9.8
addTX_df.loc[4, '2014'] = 8.3
addTX_df.loc[4, '2015'] = 6.6
addTX_df.loc[4, '2016'] = 5.3
addTX_df.loc[4, '2017'] = 4.7
addTX_df.loc[4, 'Median Household Income (2016)'] = 61308.0
addTX_df.loc[4, '% of State Median HH Income'] = 0.905383
addTX_df
# Out:
#                       City  2016_Pop  2017_Pop  Pop_Change  Percent_Change  \
# 0       San Antonio, Texas   1487738   1511946       24208             1.6
# 1         Phoenix, Arizona   1602042   1626078       24036             1.5
# 2            Dallas, Texas   1322140   1341075       18935             1.4
# 3        Fort Worth, Texas    855504    874168       18664             2.2
# 4  Los Angeles, California   3981116   3999759       18643             0.5
#
#         State  FIPS                     Name  2009  2010  ...   NaN  \
# 0       Texas  48029        Bexar County, TX   6.7   7.3  ...   NaN
# 1     Arizona    NaN                     NaN   NaN   NaN  ...   NaN
# 2       Texas  48113       Dallas County, TX   8.2   8.6  ...   NaN
# 3       Texas  48439      Tarrant County, TX   7.7   8.1  ...   NaN
# 4  California  06037  Los Angeles County, CA  11.6   NaN  ...   NaN
#
#    Median Household Income (2016)  % of State Median HH Income  2010  2011  \
# 0                         53170.0                     0.939682   NaN   NaN
# 1                             NaN                          NaN   NaN   NaN
# 2                         54429.0                     0.961932   NaN   NaN
# 3                         61553.0                     1.087836   NaN   NaN
# 4                         61308.0                     0.905383  12.5  12.2
#
#    2012  2013  2014  2015  2016
# 0   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN
# 4  10.9   9.8   8.3   6.6   5.3
#
# [5 rows x 27 columns]

# %%
addTX_df.plot(kind='barh', x='City', y=['Percent_Change', '2017'])

# %%
# NEED TO LOOK AT HOW TO CHANGE THE SCALE WITH PLOTTING TWO COLUMNS ON Y AXIS

# IN MEANTIME REPEAT SAME STEPS ABOVE TO GET UNEMPLOY DATA FOR OTHER TWO CITIES & THOSE IN LOSSES
